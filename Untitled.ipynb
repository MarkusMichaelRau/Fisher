# %%
import pandas as pd
import numpy as np
import pyccl as ccl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import ListedColormap
import numpy as np
import pyccl as ccl
from Fisher_Forecaster import *
import matplotlib.pyplot as plt
import pandas as pd

# %%
cosmo_params = dict()
with open("fid_values.sh", 'r') as f:
    for line in f:
        if line[0] != '#' and line[0] != '\n':
            words = line.split("=")
            cosmo_params[words[0]] = float(words[1][:])

# %%
cosmo_params["N_eff"] = 3.046

# %%
cosmo = ccl.Cosmology(Omega_c = cosmo_params['om_m'],
                          Omega_b = cosmo_params['om_b'], 
                          h = cosmo_params['h0'],
                          A_s = cosmo_params['A_s'], 
                          n_s = cosmo_params['n_s'], 
                          Neff = cosmo_params['N_eff'], 
                          w0=cosmo_params['w0'], 
                          wa=cosmo_params['wa'])

# %%
z_dNdz = np.loadtxt("tomo_lensing.dat")
z = z_dNdz[:, 0]
dNdz = z_dNdz[:, 1:]
nbins = dNdz.shape[-1]

# %%
tracers = []
for i in range(dNdz.shape[-1]):
    # We need (z, dNdz) as a tuple for CCL:
    z_dNdz = (z, dNdz[:, i])
    
    # We mostly will use the defaults here. By using the defaults, we are assuming 
    # that there are no intrinsic alignments affecting this tracer (not physically realistic
    # but the simplest case for debugging.)
    tracers.append(ccl.WeakLensingTracer(cosmo, dndz=z_dNdz))

# %%
orderings = [(i, j) for j in range(1, nbins+1) for i in range(1, j+1)]

# %%
p_ka = np.loadtxt("ccl_cosmosis_binned_comparison/out_ccl/pk_nl.dat")
k = np.loadtxt("ccl_cosmosis_binned_comparison/out_ccl/k.dat")
a = np.loadtxt("ccl_cosmosis_binned_comparison/out_ccl/a.dat")

# %%
p_ka.shape
# Out:
# (101, 399)

# %%
k.shape
# Out:
# (399,)

# %%
a.shape
# Out:
# (101,)

# %%
pka_ccl = ccl.Pk2D(cosmo=cosmo, pk_arr=np.log(p_ka), a_arr=a, lk_arr=np.log(k), is_logp=True)
# Out:
# ---------------------------------------------------------------------------
# CCLError                                  Traceback (most recent call last)
# <ipython-input-34-e8f1a570ec88> in <module>
# ----> 1 pka_ccl = ccl.Pk2D(cosmo=cosmo, pk_arr=np.log(p_ka), a_arr=a, lk_arr=np.log(k), is_logp=True)
#
# ~/usr/anaconda3/envs/ccl_env/lib/python3.7/site-packages/pyccl/pk2d.py in __init__(self, pkfunc, a_arr, lk_arr, pk_arr, is_logp, extrap_order_lok, extrap_order_hik, cosmo)
#     102                                                         int(extrap_order_hik),
#     103                                                         int(is_logp), status)
# --> 104         check(status)
#     105         self.has_psp = True
#     106
#
# ~/usr/anaconda3/envs/ccl_env/lib/python3.7/site-packages/pyccl/pyutils.py in check(status, cosmo)
#      27     # Check for known error status
#      28     if status in error_types.keys():
# ...

# %%
cls = []
ells = np.arange(76, 1000)
for ordering in orderings:
    index1 = ordering[0] - 1
    index2 = ordering[1] - 1
    cls.append(ccl.angular_cl(cosmo, tracers[index1], tracers[index2], ell=ells, p_of_k_a=p_ka))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-77dee51f92a3> in <module>
#       4     index1 = ordering[0] - 1
#       5     index2 = ordering[1] - 1
# ----> 6     cls.append(ccl.angular_cl(cosmo, tracers[index1], tracers[index2], ell=ells, p_of_k_a=p_ka))
#
# ~/usr/anaconda3/envs/ccl_env/lib/python3.7/site-packages/pyccl/cls.py in angular_cl(cosmo, cltracer1, cltracer2, ell, p_of_k_a, l_limber)
#      49             psp = p_of_k_a.psp
#      50         else:
# ---> 51             raise ValueError("p_of_k_a must be either a "
#      52                              "pyccl.Pk2D object or None")
#      53     else:
#
# ValueError: p_of_k_a must be either a pyccl.Pk2D object or None

# %% [markdown]
# Set up probe info

# %%
probe = "lensing"
bin_type = "equal_size"
nbins = 5
deriv_order = 2
derivs_to_calc = "all"
use_binned = True

# %%
F = Fisher_Forecaster(probe, bin_type, nbins, deriv_order, derivs_to_calc, use_binned=use_binned)

# %%
F.cosmo_params
# Out:
# {'om_m': 0.25,
#  'w0': -0.9,
#  'wa': 0.0,
#  'h0': 0.72,
#  'A_s': 2.1e-09,
#  'om_b': 0.04,
#  'n_s': 0.96,
#  'galbias': 1.0,
#  'lmin': 76.0,
#  'lmax': 999.0,
#  'deltal': 1.0,
#  'N_eff': 3.046}

# %%
F.get_tomo_data(to_save=False)
# Out:
# Calculating 5 bins of equal_size
# sig_ep^2 =  0.23
# n_g =  [[1.19105026e+08 1.14729559e+08 4.79063899e+07 1.74947572e+07
#   6.22262149e+06]]
# num dens =  [[1.03569588e+09 9.97648343e+08 4.16577303e+08 1.52128323e+08
#   5.41097521e+07]]

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = 9, 6

# %%
for i in range(1, 6):
    plt.plot(F.z_dNdz[:, 0][F.z_dNdz[:, i] != 0], F.z_dNdz[:, i][F.z_dNdz[:, i] != 0], label="Bin %d"%i)
    plt.axvline(F.z_dNdz[F.z_dNdz[:, i].argmax(), 0] )
plt.legend()
# plt.vlines()

# %%
(F.z_dNdz[:, 4] != 0).argmax()
# Out:
# 180

# %%
plt.figure(figsize=(9,6))
for i in range(1, 6):
    plt.plot(F.z_dNdz[:, 0], F.z_dNdz[:, i], label="Bin %d"%i)
    plt.xlabel("z")
    plt.ylabel(r"$dN/dz$")
plt.legend()
plt.show()

# %%
sns.set_context('paper',font_scale=1.4)

# %%
colors = ["#000000", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2",  "#D55E00", "#CC79A7", "#000000", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2",  "#D55E00", "#CC79A7"]
colors = ["#006BA4", "#FF800E", "#ABABAB", "#595959", "#5F9ED1"]

# %%
plt.figure(figsize=(9,6))
for i in range(1, 6):
    plt.plot(F.z_dNdz[:, 0], F.z_dNdz[:, i], label="Bin %d"%i, c=colors[i-1], lw=1.)
    plt.xlabel("z")
    plt.ylabel(r"$dN/dz$ (normalized)")
plt.legend()
plt.show()

# %%
xlocs = [0.7/2-0.1 + 0.7*(i) for i in range(6)]
plt.figure(figsize=(9,6))
for i in range(1, 6):
    l = plt.plot(F.z_dNdz[:, 0], F.z_dNdz[:, i], c='k', lw=1.)
#     plt.annotate("Bin %d"%i, (0.7/2-0.1 + 0.7*(i-1), 0.05))
plt.annotate("Bin 1", (xlocs[0], 0.4))
plt.annotate("Bin 2", (xlocs[1], 0.3))
plt.annotate("Bin 3", (xlocs[2], 0.15))
plt.annotate("Bin 4", (xlocs[3], 0.1))
plt.annotate("Bin 5", (xlocs[4], 0.05))
plt.xlabel("z")
plt.ylabel(r"$dN/dz$ (normalized)")
plt.show()

# %%
xlocs = [0.7/2-0.1 + 0.7*(i) - 0.04 for i in range(6)]
plt.figure(figsize=(9,6))
for i in range(1, 6):
    l = plt.plot(F.z_dNdz[:, 0], F.z_dNdz[:, i], c='k', lw=1.)
#     plt.annotate("Bin %d"%i, (0.7/2-0.1 + 0.7*(i-1), 0.05))
plt.annotate("Bin 1", (xlocs[0], 0.07))
plt.annotate("Bin 2", (xlocs[1], 0.07))
plt.annotate("Bin 3", (xlocs[2], 0.07))
plt.annotate("Bin 4", (xlocs[3], 0.11))
plt.annotate("Bin 5", (xlocs[4], 0.05))
plt.xlabel("z")
plt.ylabel(r"$dN/dz$ (normalized)")
plt.show()
